# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ вакансий на hh.ru

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
hh_data = pd.read_csv('dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних строк таблицы), чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
display(hh_data.head()) #five first rows by default
display(hh_data.tail()) #five last rows by default
display(hh_data.shape) #size of the dataset
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений

# %%
info = hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
display(hh_data.describe())
display(hh_data['Опыт работы'].nunique())
#there are two methods to determine the count of unique values in the column

display(hh_data['Ищет работу на должность:'].value_counts(normalize=True).sort_values(ascending=False))
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
hh_data['Образование'] = hh_data['Образование и ВУЗ'].apply(lambda x: list(x.split(' образование'))[0])
hh_data = hh_data.drop('Образование и ВУЗ', axis=1)
display(hh_data['Образование'].value_counts())
# Out:
# Высшее                 33863
# Среднее специальное     5765
# Неоконченное высшее     4557
# Среднее                  559
# Name: Образование, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол/возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
hh_data['Пол'] = hh_data['Пол, возраст'].apply(lambda x: 'М' if list(x.split(' , '))[0] == 'Мужчина' else 'Ж')
hh_data['Возраст'] = hh_data['Пол, возраст'].apply(lambda str_: list(str(list(str_.split(' , '))[1]).split(' '))[1])

hh_data['Возраст'] = hh_data['Возраст'].astype('int8')

display(hh_data['Пол'].value_counts(normalize=True)*100)
display(hh_data['Возраст'].value_counts())

hh_data.info()

display(hh_data['Возраст'].describe())

hh_data = hh_data.drop('Пол, возраст', axis=1)
# Out:
# М    80.929287
# Ж    19.070713
# Name: Пол, dtype: float64
# 30     2834
# 29     2765
# 28     2748
# 31     2675
# 27     2583
#        ...
# 15        2
# 100       1
# 76        1
# 77        1
# 14        1
# Name: Возраст, Length: 63, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-третьих, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def get_exp_month(exp_text) -> int:
    """
    Args:
        gender_age ([type]): [description]

    Returns:
        int: [description]
    """
    if exp_text =='' or exp_text is np.nan:
        return np.nan
    
    year_variants = ['год','года','лет']
    month_variants = ['месяц', 'месяца', 'месяцев']
    year = int(0)
    month = int(0)
    
    str_list = exp_text.split(sep=' ', maxsplit=6)
    
    for item in str_list[2:]:
        if item in year_variants:
            year = int(str_list[str_list.index(item)-1])
        if item in month_variants:
            month = int(str_list[str_list.index(item)-1])
    
    return (year*12+month)

hh_data['Опыт работы (месяц)'] = hh_data['Опыт работы'].apply(get_exp_month)
display(hh_data['Опыт работы (месяц)'].median())
hh_data = hh_data.drop('Опыт работы', axis=1)
# Out:
# 100.0

# %%
hh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Город, переезд, командировки     44744 non-null  object
#  3   Занятость                        44744 non-null  object
#  4   График                           44744 non-null  object
#  5   Последнее/нынешнее место работы  44743 non-null  object
#  6   Последняя/нынешняя должность     44742 non-null  object
#  7   Обновление резюме                44744 non-null  object
#  8   Авто                             44744 non-null  object
#  9   Образование                      44744 non-null  object
#  10  Пол                              44744 non-null  object
#  11  Возраст                          44744 non-null  int8
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов миллионников:
#
#    <code> million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#
#
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
def get_city(text) -> str:
    """[summary]

    Args:
        text ([type]): [description]

    Returns:
        str: [description]
    """
    million_cities = ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург','Нижний Новгород',
                     'Казань', 'Челябинск','Омск', 
                     'Самара', 'Ростов-на-Дону', 'Уфа', 
                     'Красноярск', 'Пермь', 'Воронеж','Волгоград']

    city = list(text.split(sep=' , ', maxsplit=1))[0]
    
    if city not in million_cities:
        city = 'другие'
        
    return city

def get_move(text) -> str:
    """[summary]

    Args:
        text ([type]): [description]

    Returns:
        str: [description]
    """
    move_trip = str(list(text.split(sep=' , ', maxsplit=1))[1]).split(' ')
    ready_to_move = bool(True)
    position = 0
    ready_count = 0

    for item in move_trip:
        
        if ((item == 'готов') or (item == 'хочу') or (item == 'готова')):
            ready_count +=1
            if ready_count ==1:
                if position > 0:
                    if move_trip[position-1] == 'не':
                        ready_to_move = False
 #                   else:
 #                       ready_to_move = True

        position +=1

    return ready_to_move

def get_trip(text) -> str:
    """[summary]

    Args:
        text ([type]): [description]

    Returns:
        str: [description]
    """
    move_trip = str(list(text.split(sep=' , ', maxsplit=1))[1]).split(' ')
    ready_for_trips = bool(True)
    position = 0
    ready_count = 0
    
    for item in move_trip:
        
        if ((item == 'готов') or (item == 'хочу') or (item == 'готова')):
            ready_count +=1
            if ready_count == 2:
                if move_trip[position-1] == 'не':
                    ready_for_trips = False
 #               else:
 #                   ready_for_trips = True
        position +=1
    
    return ready_for_trips

hh_data['Город'] = hh_data['Город, переезд, командировки'].apply(get_city)
hh_data['Готовность к переезду'] = hh_data['Город, переезд, командировки'].apply(get_move)
hh_data['Готовность к командировкам'] = hh_data['Город, переезд, командировки'].apply(get_trip)

display(hh_data['Город'].value_counts(normalize=True)*100)
display(hh_data['Готовность к переезду'].value_counts())
display(hh_data['Готовность к командировкам'].value_counts())

hh_data = hh_data.drop('Город, переезд, командировки', axis=1)
# Out:
# Москва             37.146880
# другие             35.432684
# Санкт-Петербург    11.033882
# Новосибирск         2.141069
# Казань              1.948865
# Екатеринбург        1.640443
# Самара              1.571160
# Ростов-на-Дону      1.356606
# Нижний Новгород     1.336492
# Уфа                 1.262739
# Воронеж             1.202396
# Пермь               0.994547
# Красноярск          0.909619
# Челябинск           0.737529
# Омск                0.677186
# Волгоград           0.607903
# Name: Город, dtype: float64
# False    28719
# True     16025
# Name: Готовность к переезду, dtype: int64
# True     31716
# False    13028
# Name: Готовность к командировкам, dtype: int64

# %%
display(hh_data.info())

mask = (hh_data['Готовность к переезду'] == True) & (hh_data['Готовность к командировкам'] == True)
display(hh_data[mask].shape[0]/hh_data.shape[0]*100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Занятость                        44744 non-null  object
#  3   График                           44744 non-null  object
#  4   Последнее/нынешнее место работы  44743 non-null  object
#  5   Последняя/нынешняя должность     44742 non-null  object
#  6   Обновление резюме                44744 non-null  object
#  7   Авто                             44744 non-null  object
#  8   Образование                      44744 non-null  object
#  9   Пол                              44744 non-null  object
#  10  Возраст                          44744 non-null  int8
#  11  Опыт работы (месяц)              44576 non-null  float64
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
occupation_list = ['полная занятость',
                   'частичная занятость',
                   'проектная работа',
                   'волонтерство',
                   'стажировка']

schedule_list = ['полный день', 
                 'сменный график', 
                 'гибкий график', 
                 'удаленная работа', 
                 'вахтовый метод']

hh_data['полная занятость'] = hh_data['Занятость'].apply(lambda x: True if occupation_list[0] in x else False)
hh_data['частичная занятость'] = hh_data['Занятость'].apply(lambda x: True if occupation_list[1] in x else False)
hh_data['проектная работа'] = hh_data['Занятость'].apply(lambda x: True if occupation_list[2] in x else False)
hh_data['волонтерство'] = hh_data['Занятость'].apply(lambda x: True if occupation_list[3] in x else False)
hh_data['стажировка'] = hh_data['Занятость'].apply(lambda x: True if occupation_list[4] in x else False)

hh_data['полный день'] = hh_data['График'].apply(lambda x: True if schedule_list[0] in x else False)
hh_data['сменный график'] = hh_data['График'].apply(lambda x: True if schedule_list[1] in x else False)
hh_data['гибкий график'] = hh_data['График'].apply(lambda x: True if schedule_list[2] in x else False)
hh_data['удаленная работа'] = hh_data['График'].apply(lambda x: True if schedule_list[3] in x else False)
hh_data['вахтовый метод'] = hh_data['График'].apply(lambda x: True if schedule_list[4] in x else False)

mask_occupation = (hh_data['проектная работа'] == True) & (hh_data['волонтерство'] == True)
mask_schedule = (hh_data['гибкий график'] == True) & (hh_data['вахтовый метод'] == True)

display(hh_data[mask_occupation].shape[0])
display(hh_data[mask_schedule].shape[0])
hh_data = hh_data.drop('Занятость', axis=1)
hh_data = hh_data.drop('График', axis=1)
# Out:
# 436
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
exchange_df = pd.read_csv('ExchangeRates.csv', sep=',')

exchange_df['date'] = pd.to_datetime(exchange_df['date'])
exchange_df['date'] = exchange_df['date'].dt.date
hh_data['Обновление резюме'] = pd.to_datetime(hh_data['Обновление резюме'])
hh_data['Обновление резюме'] = hh_data['Обновление резюме'].dt.date

currency_dict = {'грн':'UAH',
                 'белруб':'BYN',
                 'сум':'UZS',
                 'USD':'USD',
                 'EUR':'EUR',
                 'KGS':'KGS',
                 'AZN':'AZN',
                 'KZT':'KZT',
                 'руб':'RUR'
                 }

hh_data['ЗП число'] = hh_data['ЗП'].apply(lambda x: x.split(' ')[0])
hh_data['Валюта'] = hh_data['ЗП'].apply(lambda x: currency_dict[x.split(' ')[1].replace('.','')])

merged_df = hh_data.merge(
    exchange_df,
    left_on=['Обновление резюме','Валюта'],
    right_on=['date','currency'],
    how='left'
)

merged_df['ЗП число'] = merged_df['ЗП число'].astype('float64')

def get_salary_rur(value, currency, close, proportion):
    if currency == 'RUR':
        return value
    else:
        return value*close/proportion

merged_df['ЗП (руб)'] = merged_df.apply(lambda a: get_salary_rur(a['ЗП число'], a['Валюта'], a['close'], a['proportion']), axis=1)
display('Медианное значение ЗП: ', merged_df['ЗП (руб)'].median())

hh_data = merged_df.drop(['ЗП','Валюта','ЗП число','currency','per','date','time','close','vol','proportion'], axis=1)
display(hh_data.head())
# Out:
# 'Медианное значение ЗП: '
# 59019.0
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор        2019-04-16
# 1  Менеджер проекта, Аналитик, Технический писатель        2019-12-04
# 2                               Кассир-операционист        2019-04-16
# 3                               Инженер-программист        2019-08-04
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
hh_data_df = hh_data.copy()

fig, axes = plt.subplots(1, 2, figsize=(18,6))
histplot = sns.histplot(hh_data_df, x='Возраст', bins=100, kde=True, ax=axes[0])
boxplot = sns.boxplot(data = hh_data_df, y='Возраст', orient='v', ax=axes[1])

histplot.set_title('Распределение признака Возраст')
boxplot.set_title('Распределение признака Возраст')

print('Мода распределения Взораст :', hh_data_df['Возраст'].mode())
print('Медиана распределения Взораст :', hh_data_df['Возраст'].median())
print('Возраст большинства соискателей лежит в интервале : ', hh_data_df['Возраст'].quantile(0.25),hh_data_df['Возраст'].quantile(0.75))
# Out:
# Мода распределения Взораст : 0    30
# dtype: int8
# Медиана распределения Взораст : 31.0
# Возраст большинства соискателей лежит в интервале :  27.0 36.0

# %% [markdown]
# Мода признака равна 30 годам. Что отчетливо видно на графике расперделния (нормальный с медианой 31 год). Предельные значения 14 и 100 (скорее всего являются выбросом и нуждаются в очистке). 50% выборки приходится на возрастную группу от 27 до 36 лет.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(1,2, figsize=(18,6))

histplot = sns.histplot(data=hh_data_df, x='Опыт работы (месяц)', bins=40, ax=axes[0])
boxplot = sns.boxplot(data=hh_data_df, x='Опыт работы (месяц)', orient='v', ax=axes[1])
histplot.set_title('Распределение признака Опыт работы')
boxplot.set_title('Распределение признака Опыт работы')

print('Мода распределения Опыт работы :', hh_data_df['Опыт работы (месяц)'].mode())
print('Максимальное значение признака Опыт работы :', hh_data_df['Опыт работы (месяц)'].max())
print('Минимальное значение признака Опыт работы :', hh_data_df['Опыт работы (месяц)'].min())
# Out:
# Мода распределения Опыт работы : 0    81.0
# dtype: float64
# Максимальное значение признака Опыт работы : 1188.0
# Минимальное значение признака Опыт работы : 0.0
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# Распределение с ассиметрией в левую сторону. Мода распределения равна 81 месяц. Предельные заначения признака 0 и 1180 мес. Большинство соискателеей имеют опыт работы от 0 до 200 месяцев. Вероятно, значения больше 600 месяцев являются выбросами в распеределении.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
fig, axes = plt.subplots(1,2, figsize=(16,8))

mask = hh_data_df['ЗП (руб)'] <1000000
histplot = sns.histplot(data=hh_data_df[mask], x='ЗП (руб)', bins=40, ax=axes[0])
boxplot = sns.boxplot(data=hh_data_df, x='ЗП (руб)', ax=axes[1])
print('Максимальное значение признака ЗП (руб) :', hh_data_df['ЗП (руб)'].max())
print('Минимальное значение признака ЗП (руб) :', hh_data_df['ЗП (руб)'].min())
# Out:
# Максимальное значение признака ЗП (руб) : 24304876.0
# Минимальное значение признака ЗП (руб) : 1.0

# %%
fig1 = plt.figure(figsize=(16,8))
mask = hh_data_df['ЗП (руб)']>1000000
histplot = sns.histplot(data=hh_data_df[mask], x='ЗП (руб)', bins=1)
histplot.set_title('Число соискателей с желаемой ЗП более 1 млн руб')
# Out:
# Text(0.5, 1.0, 'Число соискателей с желаемой ЗП более 1 млн руб')

# %% [markdown]
# Чтобы ответить на вопрос, неоходимо отфильтровать по ЗП меньше 1000000 рублей. После применения фильтра видно, что данное распределение имеет ассиметричный профиль в левую сторону. Предельные значения признака - 1.0 и 24304876 рублей, примерный интервал заработнай платы большинства соискателей - 0 - 150000 руб. На данный момент анаомальное значение - 24304876 руб.s

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
fig = plt.figure(figsize=(16,8))

mask = hh_data_df['ЗП (руб)']<1000000

data = hh_data_df.groupby(by='Образование', as_index=False).median().sort_values(by='ЗП (руб)', ascending=True)
barplot = sns.barplot(data=data, y='ЗП (руб)', x='Образование')
barplot.set_title('Медианное значение ЗП от образования', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Медианное значение ЗП от образования')

# %% [markdown]
# Для высшего уровня образования наблюдаются наибольшие уровни и наименьшие уровни желаемой заработной платы для среднего уровня образования. Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы - корреляция очевидна, чем выше уровень образования тем выше ожидаемая ЗП (и не только, на самом деле фактическая тоже увеличивается с уровнем образования)

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
mask = hh_data_df['ЗП (руб)']<1000000

fig = plt.figure(figsize=(16,8))
data = hh_data_df[mask].groupby(by='Город', as_index=False)['ЗП (руб)'].median().sort_values(by= 'ЗП (руб)', ascending=False)
#решил построить эту диаграмму через группировку - следующий будет другим способом
barplot = sns.barplot(data=data, x='Город', y='ЗП (руб)')
barplot.set_title('Зависимость уровеня желаемой ЗП (максимальное значение) от Города', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Зависимость уровеня желаемой ЗП (максимальное значение) от Города')

# %% [markdown]
# Уровни желаемой заработной платы в одних из самых крупных городах как - Москва, Санкт-Петербург, Екатеринбург и Новосибирск. Как вы считаете, важен ли признак города при прогнозировании заработной платы - да, если это города перечисленные выше, остальные можно было бы сгруппировать в другие.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
fig = plt.figure(figsize=(16,16))

barplot = sns.barplot(data=hh_data_df, 
                      x='Готовность к переезду',
                      y='ЗП (руб)',
                      hue='Готовность к командировкам',
                      estimator=np.median
                      )

barplot.set_title('Зависимость готовности к переезду и готовности к командировкам к уровню желаемой ЗП(медиана)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Зависимость готовности к переезду и готовности к командировкам к уровню желаемой ЗП(медиана)')

# %% [markdown]
# Заметно соискатели готовые к перезду и к командировкам ожидают более высокий уровень дохода.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
hh_data_pivot_table = hh_data_df.pivot_table(values='ЗП (руб)',
                                             columns='Возраст',
                                             index='Образование',
                                             aggfunc=['median']
                                             )
fig = plt.figure(figsize=(18,9))
heatmap = sns.heatmap(data=hh_data_pivot_table, xticklabels=10, cmap='YlGnBu')
heatmap.set_title('Тепловая карта Образование-Возраст-ЗП (руб)', fontsize=16)

display(hh_data_pivot_table)
# Out:
#                       median                                                 \
# Возраст                  14       15         16       17       18       19
# Образование
# Высшее               60000.0      NaN  122582.49  90075.5  30000.0  30000.0
# Неоконченное высшее      NaN      NaN        NaN  80000.0  25000.0  30000.0
# Среднее                  NaN  10000.0        NaN  44000.0  35000.0  45000.0
# Среднее специальное      NaN   2000.0   30000.00  25000.0  25151.0  30000.0
#
#                                                          ...            \
# Возраст                  20       21       22       23   ...       67
# Образование                                              ...
# Высшее               30000.0  35000.0  40000.0  45000.0  ...   70000.0
# Неоконченное высшее  31000.0  35000.0  40000.0  40000.0  ...       NaN
# Среднее              29000.0  40000.0  40000.0  35000.0  ...       NaN
# Среднее специальное  30000.0  30000.0  30000.0  35000.0  ...  120000.0
#
# ...

# %% [markdown]
# Данная диаграмма еще раз подтверждает, что ожидаемый уровень ЗП находится в прямой зависимости от возраста (в большинстве случаев он имеет прямую корреляцию с оптыом работы) и образования.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
data = hh_data_df.copy()

data['Года'] = data['Опыт работы (месяц)']/12

fig = plt.figure(figsize=(16,8))
scatterplot = sns.scatterplot(data=data,
                              x='Возраст',
                              y='Года')

line = list(range(0,100))

scatterplot = sns.lineplot(data=line)

# %% [markdown]
# Конечно же опыт работы не может быть больше возможного трудового стажа и тем более возраста, предполагая что в крайнем случае люди начинают работать в 14 лет, а в среднем в 20-23 года.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
fig, axes = plt.subplots(2,2, figsize=(16,8))

histplot_1 = sns.histplot(data=hh_data_df,
                       x='Возраст',
                       hue='Готовность к переезду',
                       bins=100,
                       ax=axes[0][0],
                       )


histplot_2 = sns.histplot(data=hh_data_df,
                       x='Возраст',
                       hue='Готовность к командировкам',
                       bins=100,
                       ax=axes[0][1]
                       )

histplot_3 = sns.histplot(data=hh_data_df,
                       x='Возраст',
                       hue='полный день',
                       bins=100,
                       ax=axes[1][0]
                       )

histplot_4 = sns.histplot(data=hh_data_df,
                       x='Возраст',
                       hue='вахтовый метод',
                       bins=100,
                       ax=axes[1][1]
                       )
histplot_1.set_title('Количество соискателей готовых/не готовых на переезд к возрасту')
histplot_2.set_title('Количество соискателей готовых/не готовых к командировкам к возрасту')
histplot_3.set_title('Количество соискателей готовых/не готовых на полный день к возрасту')
histplot_4.set_title('Количество соискателей готовых/не готовых на вахтовый метод к возрасту')
# Out:
# Text(0.5, 1.0, 'Количество соискателей готовых/не готовых на вахтовый метод к возрасту')

# %% [markdown]
# Решил продемонстрировать количество желающих к переезду, готовых к командировкам, готовых к полному рабочему дню и к вахтовому методу к возрасту. Как видно доля готовых к переезду в целом одинакова, в то время как для соискателей старше 25 лет доля тех, кто готов к командировкам, выше. Доля соискателей согласных на вахтовый метод работы выше к 30 годам.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
hh_columns = hh_data_df.columns
dupl_mask = hh_data_df.duplicated(hh_columns)
display(hh_columns)
hh_data_dupl = hh_data_df[dupl_mask]
print(f'Число найденных дубликатов: {hh_data_dupl.shape[0]}')

hh_data_df_dedupl = hh_data_df.drop_duplicates(subset=hh_columns)
print(f'Число записей до очистки: {hh_data_df.shape[0]}')
print(f'Число записей после очистки: {hh_data_df_dedupl.shape[0]}')
# Out:
# Index(['Ищет работу на должность:', 'Последнее/нынешнее место работы',
#        'Последняя/нынешняя должность', 'Обновление резюме', 'Авто',
#        'Образование', 'Пол', 'Возраст', 'Опыт работы (месяц)', 'Город',
#        'Готовность к переезду', 'Готовность к командировкам',
#        'полная занятость', 'частичная занятость', 'проектная работа',
#        'волонтерство', 'стажировка', 'полный день', 'сменный график',
#        'гибкий график', 'удаленная работа', 'вахтовый метод', 'ЗП (руб)'],
#       dtype='object')
# Число найденных дубликатов: 161
# Число записей до очистки: 44744
# Число записей после очистки: 44583

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
null_col_mean = hh_data_df_dedupl.isnull().mean()*100
col_with_null = null_col_mean[null_col_mean>0]

print(col_with_null)
print('Число пропусков в столбце Опыт работы (месяц) :', hh_data_df_dedupl.shape[0] - hh_data_df_dedupl['Опыт работы (месяц)'].describe()['count'])
# Out:
# Последнее/нынешнее место работы    0.002243
# Последняя/нынешняя должность       0.004486
# Опыт работы (месяц)                0.372339
# dtype: float64
# Число пропусков в столбце Опыт работы (месяц) : 166.0

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
hh_data_drop = hh_data_df_dedupl.copy()

values = {'Опыт работы (месяц)':hh_data_drop['Опыт работы (месяц)'].median()}
hh_data_drop = hh_data_drop.fillna(value=values)
hh_data_drop = hh_data_drop.dropna(how='any', axis=0)
print(hh_data_drop.isnull().mean()) #проверка остались ли пропуски
print(hh_data_drop['Опыт работы (месяц)'].mean())
# Out:
# Ищет работу на должность:          0.0
# Последнее/нынешнее место работы    0.0
# Последняя/нынешняя должность       0.0
# Обновление резюме                  0.0
# Авто                               0.0
# Образование                        0.0
# Пол                                0.0
# Возраст                            0.0
# Опыт работы (месяц)                0.0
# Город                              0.0
# Готовность к переезду              0.0
# Готовность к командировкам         0.0
# полная занятость                   0.0
# частичная занятость                0.0
# проектная работа                   0.0
# волонтерство                       0.0
# стажировка                         0.0
# полный день                        0.0
# сменный график                     0.0
# гибкий график                      0.0
# удаленная работа                   0.0
# вахтовый метод                     0.0
# ЗП (руб)                           0.0
# dtype: float64
# 114.35328951795609

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
mask = (hh_data_drop['ЗП (руб)'] < 1000) | (hh_data_drop['ЗП (руб)'] > 1000000)
print('Количество записей до очистки : ', hh_data_drop.shape[0])
print(hh_data_drop[mask].describe()) #получение количества выбросов
index_list = hh_data_drop[mask].index
hh_data_drop = hh_data_drop.drop(index_list)
print('Количество записей после очистки : ',hh_data_drop.shape[0])
# Out:
# Количество записей до очистки :  44581
#          Возраст  Опыт работы (месяц)      ЗП (руб)
# count  89.000000            89.000000  8.900000e+01
# mean   36.202247           156.775281  4.409636e+05
# std     9.275064            90.564863  2.719130e+06
# min    20.000000            15.000000  1.000000e+00
# 25%    29.000000            85.000000  5.000000e+01
# 50%    34.000000           139.000000  1.000000e+02
# 75%    42.000000           218.000000  2.500000e+02
# max    60.000000           401.000000  2.430488e+07
# Количество записей после очистки :  44492

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
mask =  hh_data_drop['Возраст'] <= hh_data_drop['Опыт работы (месяц)']/12
index_list = hh_data_drop[mask].index
print('Количество записей до очистки : ', hh_data_drop.shape[0])
print('Количество вбросов : ', hh_data_drop[mask].shape[0])
hh_data_drop = hh_data_drop.drop(index_list)
print('Количество записей после очистки : ',hh_data_drop.shape[0])
# Out:
# Количество записей до очистки :  44492
# Количество вбросов :  7
# Количество записей после очистки :  44485

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**? В какую сторону **асимметрично логарифмическое распределение**? Найдите выбросы с помощью **метода z-отклонения** и удалите их из данных, используйте логарифмический масштаб, сделайте **послабление на 1 сигму (возьмите 4 сигмы)** в сторону, противоположную асимметрии.

# %%
log_hh_age = np.log(hh_data_drop['Возраст'])
fig, axes = plt.subplots(1,2, figsize=(18,8))
#гистограмма исходного признака
histplot_norm = sns.histplot(hh_data_drop['Возраст'], bins=60, ax=axes[0])
histplot_norm.set_title('Гистограмма исходного признака')
#гистограмма в логарифмическом масштабе
histplot_log = sns.histplot(log_hh_age, bins=60, ax=axes[1])
histplot_log.set_title('Гистограмма в логарифмическом масштабе')

def outliers_z_score(data, feature, log_scale=False, left = 3, right = 3):
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
    
    mu = x.astype('float').mean()
    sigma = x.astype('float').std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x > lower_bound) & (x < upper_bound)]
    return outliers, cleaned

outliers, cleaned = outliers_z_score(hh_data_drop, 'Возраст', log_scale=True, left=3, right=4)
print('Осталось после исключения выбросов по методу z-отклонения : ', cleaned.shape[0])
print('Количество выбросов по методу z-отклонению : ', outliers.shape[0])

fig1 = plt.figure(figsize=(18,8))

histplot_cleaned = sns.histplot(cleaned['Возраст'], bins=60)
histplot_cleaned.set_title('Гистограмма "Возраст" после исключения выбросов по методу z-отклонения')
# Out:
# Осталось после исключения выбросов по методу z-отклонения :  44482
# Количество выбросов по методу z-отклонению :  3
# Text(0.5, 1.0, 'Гистограмма "Возраст" после исключения выбросов по методу z-отклонения')
